# %%
import pandas as pd
import shutil
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

# %%
shutil.unpack_archive('Data/ECG5000.zip', '/Data')

# %%
train = pd.read_csv('Data/ECG5000_TRAIN.txt', delimiter= '\s+', index_col=False, header=None)
test = pd.read_csv('Data/ECG5000_TEST.txt', delimiter= '\s+', index_col=False, header=None)

# %%
# Concatenate the Datasets
data = pd.concat((train, test))
data.shape
# Out:
# (5000, 141)

# %%
# Shuffle the Data
data = data.sample(frac=1.0).reset_index(drop=True)

# %%
data.columns = ['target'] + [str(i+1) for i in range(140)]

# %%
sns.countplot(data=data, x='target')
plt.show()
print(data.target.value_counts())
# Out:
# 1.0    2919
# 2.0    1767
# 4.0     194
# 3.0      96
# 5.0      24
# Name: target, dtype: int64

# %% [markdown]
# - 1.0 represents the normal signal
# - 2.0, 3.0, 4.0, 5.0 represents the anomaly signal

# %% [markdown]
# ### Data Preprocessing
#
# 1 is Normal
#
# 0 is Anomaly

# %%
data['target'] = data['target'].apply(lambda x: 1 if x==1.0 else 0.0)

# %%
print(data.target.value_counts())
# Out:
# 1.0    2919
# 0.0    2081
# Name: target, dtype: int64

# %%
# Make Label y
y = data['target']

# Make Feature Batch
X = data.drop('target', axis=1)

# %%
# Train Test split of Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, shuffle=True)

# %%
y_train = y_train.astype(bool)

# %%
X_train_normal = X_train[y_train].values # All Normal Samples for Training
X_train_anomaly = X_train[~y_train].values # All Anomaly Samples for Evaluation

# %% [markdown]
# ### Scaling

# %%
def minmax(scale_min=0.0, scale_max=1.0):
    max_val = np.max(X_train_normal)
    min_val = np.min(X_train_normal)
    X_train_normal = (scale_max - scale_min) * (X_train_normal - min_val) / (max_val - min_val) + scale_min
    X_train_anomaly = (scale_max - scale_min) * (X_train_anomaly - min_val) / (max_val - min_val) + scale_min
    X_test = (scale_max - scale_min) * (X_test - min_val) / (max_val - min_val) + scale_min
    return X_train_normal, X_train_anomaly, X_test
    

def standardize():
    mean = np.mean(X_train_normal)
    std = np.std(X_train_normal)
    X_train_normal = (X_train_normal - mean) / std
    X_train_anomaly = (X_train_anomaly - mean) / std
    X_test = (X_test - mean) / std
    return X_train_normal, X_train_anomaly, X_test
    
    
#X_train_normal, X_train_anomaly, X_test = standardize()
#X_train_normal, X_train_anomaly, X_test = minmax()

# %% [markdown]
# ### Fully Connected Neural Network Autoencoder

# %%
model_dense = tf.keras.Sequential([
    Dense(64, activation='relu', input_shape=(140,)),
    #Dropout(0.2),
    Dense(16, activation='relu'),
    #Dropout(0.2),
    Dense(8, activation='relu'),  # Bottleneck Layer
    #Dropout(0.2),
    Dense(16, activation='relu'),
    #Dropout(0.2),
    Dense(64, activation='relu'),
    #Dropout(0.2),
    Dense(140, activation='relu')
])
model_dense.compile(optimizer='adam', loss='mse')
print(model_dense.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                9024
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                144
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                1088
# _________________________________________________________________
# dense_5 (Dense)              (None, 140)               9100
# =================================================================
# Total params: 20,532
# Trainable params: 20,532
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def train(model,
          X_train,
          X_eval,
          epochs=20):
    X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
    X_eval = tf.convert_to_tensor(X_eval, dtype=tf.float32)

    # Train model on Normal Train Data (Normal Data Only)
    # Validate Model on complete Test Set (Normal + Anomaly)
    history = model.fit(X_train,
                        X_train,
                        epochs=epochs,
                        #batch_size=500,
                        validation_data=(X_eval, X_eval),
                        shuffle=True)
    
    # Plot Losses
    plt.figure()
    plt.plot(history.history['loss'], label='Normal Data Loss')
    plt.plot(history.history['val_loss'], label='Anomaly Data Loss')
    plt.legend()
    plt.title('Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.savefig('Plots/FC_Training_Losses.png')
    plt.show()

    # Reconstruction Losses of Normal + Anomaly Data
    train_pred = model.predict(X_train)
    train_loss = tf.keras.losses.mae(train_pred, X_train).numpy()
    print('Train Loss', np.mean(train_loss))

    test_pred = model.predict(X_eval)
    val_loss = tf.keras.losses.mae(test_pred, X_eval).numpy()
    print('Test Loss', np.mean(val_loss))
    
    sns.histplot(train_loss, color='green', kde=True)    
    sns.histplot(val_loss, color='yellow', kde=True)
    plt.savefig('Plots/FC_Training_Histogram.png')
    plt.title('Training Loss of all Samples - Fully Connected Network')
    plt.show()
    
    threshold = 0.5
    return threshold

# %%
# Train with Normal Data, Evaluate with anomaly data
threshold = train(model_dense,
                  X_train=X_train_normal,
                  X_eval=X_train_anomaly,
                  epochs=40)
# Out:
# Epoch 1/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.9340 - val_loss: 0.9832
# Epoch 2/40
# 28/28 [==============================] - 0s 2ms/step - loss: 0.8166 - val_loss: 0.9849
# Epoch 3/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.8059 - val_loss: 0.9807
# Epoch 4/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.8030 - val_loss: 0.9829
# Epoch 5/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7979 - val_loss: 0.9711
# Epoch 6/40
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7808 - val_loss: 0.9495
# Epoch 7/40
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7537 - val_loss: 0.9456
# Epoch 8/40
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7359 - val_loss: 0.9441
# Epoch 9/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7213 - val_loss: 0.9496
# Epoch 10/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7179 - val_loss: 0.9433
# Epoch 11/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7162 - val_loss: 0.9433
# Epoch 12/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7147 - val_loss: 0.9432
# Epoch 13/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7086 - val_loss: 0.9360
# Epoch 14/40
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7042 - val_loss: 0.9381
# Epoch 15/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7032 - val_loss: 0.9334
# Epoch 16/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7024 - val_loss: 0.9363
# Epoch 17/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7011 - val_loss: 0.9380
# Epoch 18/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6982 - val_loss: 0.9311
# Epoch 19/40
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6972 - val_loss: 0.9314
# Epoch 20/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6967 - val_loss: 0.9299
# Epoch 21/40
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6962 - val_loss: 0.9251
# Epoch 22/40
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6957 - val_loss: 0.9293
# Epoch 23/40
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6956 - val_loss: 0.9229
# Epoch 24/40
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6953 - val_loss: 0.9231
# Epoch 25/40
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6952 - val_loss: 0.9212
# Epoch 26/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6949 - val_loss: 0.9228
# Epoch 27/40
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6946 - val_loss: 0.9273
# Epoch 28/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6944 - val_loss: 0.9251
# Epoch 29/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6942 - val_loss: 0.9243
# Epoch 30/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6940 - val_loss: 0.9273
# Epoch 31/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6938 - val_loss: 0.9216
# Epoch 32/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6939 - val_loss: 0.9215
# Epoch 33/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6936 - val_loss: 0.9206
# Epoch 34/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6933 - val_loss: 0.9301
# Epoch 35/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6932 - val_loss: 0.9234
# Epoch 36/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6928 - val_loss: 0.9236
# Epoch 37/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6927 - val_loss: 0.9233
# Epoch 38/40
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6924 - val_loss: 0.9250
# Epoch 39/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6923 - val_loss: 0.9205
# Epoch 40/40
# 28/28 [==============================] - 0s 5ms/step - loss: 0.6922 - val_loss: 0.9270
# Train Loss 0.4232392
# Test Loss 0.5708725

# %%
def evaluation(X_test, y_test, threshold, dataset='Test'):
    test_pred = model_dense.predict(X_test)
    test_loss = tf.keras.losses.mae(test_pred, X_test).numpy()
    test_pred = (test_loss < threshold).astype(int)
    test_true = y_test.values.astype(int)

    acc = accuracy_score(test_true, test_pred)
    recall = recall_score(test_true, test_pred)
    precision = precision_score(test_true, test_pred)
    cm = confusion_matrix(test_true, test_pred)


    print(dataset + ' Accuracy', acc)
    print(dataset + ' Recall', recall)
    print(dataset + ' Precision', precision)
    print('\nConfusion Matrix:\n',cm)

# %%
evaluation(X_train, y_train, threshold, dataset='Training')
# Out:
# Training Accuracy 0.944
# Training Recall 0.9334862385321101
# Training Precision 0.969047619047619
#
# Confusion Matrix:
#  [[602  26]
#  [ 58 814]]

# %%
evaluation(X_test, y_test, threshold, dataset='Test')
# Out:
# Test Accuracy 0.9334285714285714
# Test Recall 0.925256472887152
# Test Precision 0.9594731509625126
#
# Confusion Matrix:
#  [[1373   80]
#  [ 153 1894]]

# %%
def show_recon_series(model, batch=X_test.values, labels=y_test.values):
    pred = model.predict(batch)
    pred_losses = tf.keras.losses.mae(pred, batch).numpy()
    
    sns.histplot(pred_losses, color='black', kde=True)
    plt.show()
    
    for i in range(10):
        if labels[i] == 0:
            label = 'Anomaly'
        else:
            label = 'Normal'
        plt.plot(pred[i], label='Prediction')
        plt.plot(batch[i, :], label='True')
        plt.title(label + '  Loss:' + str(np.round(pred_losses[i],2)))
        plt.legend()
        plt.show()

# %%
show_recon_series(model=model_dense)
