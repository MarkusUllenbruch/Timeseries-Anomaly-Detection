# %% [markdown]
# # Autoencoder with Fully Connected Layers
#
# #### by Markus Ullenbruch

# %%
# Load Imports
import pandas as pd
import shutil
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
shutil.unpack_archive('Data/ECG5000.zip', '/Data') # Unpack Dataset

# %%
train = pd.read_csv('Data/ECG5000_TRAIN.txt', delimiter= '\s+', index_col=False, header=None)
test = pd.read_csv('Data/ECG5000_TEST.txt', delimiter= '\s+', index_col=False, header=None)

# %%
# Concatenate the two Datasets
data = pd.concat((train, test))
data.shape
# Out:
# (5000, 141)

# %%
# Shuffle the Data
data = data.sample(frac=1.0).reset_index(drop=True)

# %%
# Make columns
data.columns = ['target'] + [str(i+1) for i in range(140)]

# %%
data.head()
# Out:
#    target         1         2         3         4         5         6  \
# 0     1.0 -1.619197 -4.350438 -4.236441 -4.408360 -2.938991 -1.789518
# 1     2.0 -3.106170 -3.537044 -2.905321 -3.061512 -2.377308 -1.973649
# 2     1.0 -0.139691 -2.550819 -3.568496 -4.254889 -3.997047 -3.026436
# 3     1.0 -0.959165 -2.560351 -2.921442 -3.659787 -3.590564 -3.031305
# 4     1.0 -0.167967 -1.915351 -3.346299 -3.841084 -3.890582 -3.758489
#
#           7         8         9  ...       131       132       133       134  \
# 0 -1.439442 -0.824916  0.049870  ... -0.020221  0.733353  0.616048  0.547728
# 1 -1.414118 -1.200546 -1.039872  ...  0.082924 -0.091951 -0.439347 -1.179372
# 2 -1.741868 -1.570393 -1.058867  ...  0.676104  1.398897  1.197609  0.950449
# 3 -2.241236 -1.776232 -1.188609  ...  2.492674  0.771102  1.653328  2.153280
# 4 -3.253141 -2.161581 -1.541460  ...  0.749067  0.858803  0.903102  0.660534
#
#         135       136       137       138       139       140
# 0  0.174063 -0.534051 -0.706788 -0.343483  0.301902 -2.907078
# 1 -1.754067 -2.388430 -3.563661 -3.558971 -4.042897 -2.380839
# 2  0.916011  0.611303  0.534751  0.261311  0.721416  0.536381
# 3  0.210780 -0.031066  0.600180  0.250021  1.329884  0.125582
# 4  0.454661  0.451448  0.862588  0.466269 -1.105989 -3.106276
#
# [5 rows x 141 columns]

# %%
sns.countplot(data=data, x='target')
plt.show()
print(data.target.value_counts())
# Out:
# 1.0    2919
# 2.0    1767
# 4.0     194
# 3.0      96
# 5.0      24
# Name: target, dtype: int64

# %% [markdown]
# - 1.0 represents the normal signal
# - 2.0, 3.0, 4.0, 5.0 represents the anomaly signal

# %% [markdown]
# ### Data Preprocessing
#
# 1 is Normal
#
# 0 is Anomaly

# %%
# Make binary labels
data['target'] = data['target'].apply(lambda x: 1.0 if x==1.0 else 0.0)

# %%
data.describe()
# Out:
#             target            1            2            3            4  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.583800    -0.262476    -1.649511    -2.492211    -3.119443
# std       0.492977     1.152369     1.445493     1.386409     1.302802
# min       0.000000    -6.729499    -7.090374    -5.132459    -5.363241
# 25%       0.000000    -1.004511    -2.701576    -3.668096    -4.227247
# 50%       1.000000    -0.297541    -1.661892    -2.585677    -3.387934
# 75%       1.000000     0.500061    -0.677290    -1.513964    -2.235369
# max       1.000000     4.966414     3.479689     2.660597     1.899798
#
#                  5            6            7            8            9  ...  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean     -3.167438    -2.866308    -2.273126    -1.798127    -1.410124  ...
# std       1.104382     0.906133     0.731627     0.623100     0.637149  ...
# min      -5.375715    -5.330194    -4.782240    -4.311288    -4.071361  ...
# 25%      -4.007470    -3.480479    -2.779941    -2.165851    -1.774124  ...
# 50%      -3.468718    -2.947061    -2.285578    -1.750157    -1.422570  ...
# 75%      -2.530967    -2.398813    -1.823494    -1.484923    -1.063708  ...
# max       2.147015     1.614375     1.868728     1.804251     1.683730  ...
#
#                131          132          133          134          135  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.146319     0.070973    -0.062914    -0.276206    -0.507667
# std       1.171299     1.404842     1.646585     1.895134     2.059758
# min      -3.971715    -4.167040    -4.557576    -4.530488    -4.563270
# 25%      -0.655753    -1.089300    -1.588885    -2.147449    -2.731550
# 50%       0.473642     0.658318     0.717808     0.604747     0.334857
# 75%       1.062134     1.169420     1.238687     1.264471     1.234433
# max       2.960969     3.007606     2.854680     2.912394     2.937685
#
#                136          137          138          139          140
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     -0.761043    -0.834741    -0.642263    -0.487242    -0.706008
# std       2.086218     2.056220     1.859296     1.830987     1.414465
# min      -5.150100    -4.880460    -5.496107    -5.880890    -6.092227
# 25%      -3.030509    -2.868331    -2.153513    -1.657771    -1.596692
# 50%      -0.030767    -0.195151    -0.194423    -0.160262    -0.565588
# 75%       1.034584     0.945237     0.951681     1.002692     0.272012
# max       3.351437     3.432519     3.579448     4.425976     7.402103
#
# [8 rows x 141 columns]

# %%
print(data.target.value_counts())
# Out:
# 1.0    2919
# 0.0    2081
# Name: target, dtype: int64

# %%
# Make Label Data y
y = data['target']

# Make Feature Data
X = data.drop('target', axis=1)

# %%
# Train Test split of Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.65, shuffle=True)

# %%
y_train = y_train.astype(bool)  # Make boolean of 1,0 coded train label, create a mask
y_test = y_test.astype(bool)

# %%
X_train_normal = X_train[y_train].values # All Normal Samples for Training
X_train_anomaly = X_train[~y_train].values # All Anomaly Samples for Evaluation

print('Train Normal Shape:', X_train_normal.shape, '\nTrain Anomaly Shape:', X_train_anomaly.shape)
# Out:
# Train Normal Shape: (1024, 140)
# Train Anomaly Shape: (726, 140)

# %% [markdown]
# ### Fully Connected Neural Network Autoencoder

# %%
def make_model(loss):
    model = tf.keras.Sequential([
        Dense(64, activation='relu', input_shape=(140,)),
        Dense(16, activation='relu'),
        Dense(8, activation='relu'),  # Bottleneck Layer
        Dense(16, activation='relu'),
        Dense(64, activation='relu'),
        Dense(140, activation='relu')
    ])
    model.compile(optimizer='adam', loss=loss)
    print(model.summary())
    return model

# %%
def train(model,
          X_train,
          X_eval,
          loss,
          epochs=20):
    X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
    X_eval = tf.convert_to_tensor(X_eval, dtype=tf.float32)

    # Train model on Normal Train Data (Normal Data Only)
    # Validate Model on complete Test Set (Normal + Anomaly)
    history = model.fit(X_train,
                        X_train,
                        epochs=epochs,
                        #batch_size=500,
                        validation_data=(X_eval, X_eval),
                        shuffle=True)
    
    # Plot Losses
    plt.figure()
    plt.plot(history.history['loss'], label='Normal Data Loss', color='green')
    plt.plot(history.history['val_loss'], label='Anomaly Data Loss', color='red')
    plt.legend()
    plt.title('Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.savefig('Plots/FC_Training_Losses.png')
    plt.show()

    # Reconstruction Losses of Normal + Anomaly Data
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_eval)
    
    if loss == 'mse':
        train_loss = tf.keras.losses.mse(train_pred, X_train).numpy()
        val_loss = tf.keras.losses.mse(test_pred, X_eval).numpy()
    if loss == 'mae':
        train_loss = tf.keras.losses.mae(train_pred, X_train).numpy()
        val_loss = tf.keras.losses.mae(test_pred, X_eval).numpy()
    
    print('Train Loss', np.mean(train_loss))
    print('Test Loss', np.mean(val_loss))
    
    #threshold = 0.5
    threshold = np.mean(train_loss) + 1.8*np.std(train_loss)
    
    sns.histplot(train_loss, color='green', kde=True)    
    sns.histplot(val_loss, color='red', kde=True)
    plt.axvline(x=threshold)
    plt.savefig('Plots/FC_Training_Histogram.png')
    plt.title('Training Loss of all Samples - Fully Connected Network')
    plt.show()
    
    return threshold

# %%
loss = 'mse'

# %%
# Make Model and Train with Normal Data, Evaluate with anomaly data
model_dense = make_model(loss=loss) # 'mse' or 'mae'

threshold = train(model=model_dense,
                  X_train=X_train_normal,
                  X_eval=X_train_anomaly,
                  epochs=35,
                  loss=loss)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                9024
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                144
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                1088
# _________________________________________________________________
# dense_5 (Dense)              (None, 140)               9100
# =================================================================
# Total params: 20,532
# Trainable params: 20,532
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/35
# 32/32 [==============================] - 0s 6ms/step - loss: 0.8929 - val_loss: 0.9734
# Epoch 2/35
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7986 - val_loss: 0.9758
# Epoch 3/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7867 - val_loss: 0.9677
# Epoch 4/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7720 - val_loss: 0.9607
# Epoch 5/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7501 - val_loss: 0.9650
# Epoch 6/35
# 32/32 [==============================] - ETA: 0s - loss: 0.740 - 0s 3ms/step - loss: 0.7407 - val_loss: 0.9545
# Epoch 7/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7375 - val_loss: 0.9551
# Epoch 8/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7349 - val_loss: 0.9542
# Epoch 9/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7314 - val_loss: 0.9494
# Epoch 10/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7275 - val_loss: 0.9430
# Epoch 11/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7229 - val_loss: 0.9384
# Epoch 12/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7203 - val_loss: 0.9389
# Epoch 13/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7193 - val_loss: 0.9368
# Epoch 14/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7188 - val_loss: 0.9342
# Epoch 15/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7181 - val_loss: 0.9380
# Epoch 16/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7165 - val_loss: 0.9353
# Epoch 17/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7148 - val_loss: 0.9377
# Epoch 18/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7143 - val_loss: 0.9342
# Epoch 19/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7137 - val_loss: 0.9341
# Epoch 20/35
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7128 - val_loss: 0.9307
# Epoch 21/35
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7126 - val_loss: 0.9355
# Epoch 22/35
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7122 - val_loss: 0.9333
# Epoch 23/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7118 - val_loss: 0.9262
# Epoch 24/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7115 - val_loss: 0.9269
# Epoch 25/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7113 - val_loss: 0.9231
# Epoch 26/35
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7109 - val_loss: 0.9198
# Epoch 27/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7106 - val_loss: 0.9173
# Epoch 28/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7103 - val_loss: 0.9147
# Epoch 29/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7099 - val_loss: 0.9106
# Epoch 30/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7095 - val_loss: 0.9113
# Epoch 31/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7092 - val_loss: 0.9051
# Epoch 32/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7090 - val_loss: 0.9081
# Epoch 33/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7088 - val_loss: 0.9066
# Epoch 34/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7087 - val_loss: 0.9069
# Epoch 35/35
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7084 - val_loss: 0.9117
# Train Loss 0.708166
# Test Loss 0.9117216

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title=' Confusion matrix',
                          cmap=None,
                          normalize=True,
                          dataset='_'):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(dataset + title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.savefig('Plots/cm' + dataset + '.png')
    plt.show()

# %%
def evaluation(X_test, y_test, threshold, dataset='Test'):
    test_pred = model_dense.predict(X_test)
    test_loss = tf.keras.losses.mse(test_pred, X_test).numpy()
    test_pred = (test_loss < threshold).astype(int)
    test_true = y_test.values.astype(int)

    acc = accuracy_score(test_true, test_pred)
    recall = recall_score(test_true, test_pred)
    precision = precision_score(test_true, test_pred)
    cm = confusion_matrix(test_true, test_pred, normalize=None)
    plot_confusion_matrix(cm, ['Anomaly', 'Normal'], normalize=False, dataset=dataset)


    print(dataset + ' Accuracy', acc)
    print(dataset + ' Recall', recall)
    print(dataset + ' Precision', precision)
    print('\nConfusion Matrix:\n',cm)

# %%
evaluation(X_train, y_train, threshold, dataset='Training')
# Out:
# Training Accuracy 0.9542857142857143
# Training Recall 0.94921875
# Training Precision 0.972
#
# Confusion Matrix:
#  [[698  28]
#  [ 52 972]]

# %%
evaluation(X_test, y_test, threshold, dataset='Test')
# Out:
# Test Accuracy 0.9606153846153846
# Test Recall 0.9593667546174143
# Test Precision 0.9727126805778491
#
# Confusion Matrix:
#  [[1304   51]
#  [  77 1818]]

# %%
def show_recon_series(model, batch=X_test.values, labels=y_test.values):
    pred = model.predict(batch)
    pred_losses = tf.keras.losses.mse(pred, batch).numpy()
    
    sns.histplot(pred_losses, color='black', kde=True)
    plt.show()
    
    for i in range(10):
        if labels[i] == 0:
            label = 'Anomaly'
        else:
            label = 'Normal'
        plt.plot(pred[i], label='Prediction')
        plt.plot(batch[i, :], label='True')
        plt.title(label + '  Loss:' + str(np.round(pred_losses[i],2)))
        plt.legend()
        plt.show()

# %%
show_recon_series(model=model_dense)

# %% [markdown]
# ### Scaling of Time Series

# %%
class Scaler:
    '''Scaling Time Series'''
    def __init__(self, X_train, X_test):
        self.X_train = X_train
        self.X_test = X_test

    def minmax(self, scale_min=0.0, scale_max=1.0):
        '''scale from min to max'''
        max_val = np.max(self.X_train)
        min_val = np.min(self.X_train)
        X_train = (scale_max - scale_min) * (self.X_train - min_val) / (max_val - min_val) + scale_min
        X_test = (scale_max - scale_min) * (self.X_test - min_val) / (max_val - min_val) + scale_min
        return X_train, X_test

    def standardize(self):
        '''Make mean=0 and std=1'''
        mean = np.mean(self.X_train)
        std = np.std(self.X_train)
        X_train = (self.X_train - mean) / std
        X_test = (self.X_test - mean) / std
        return X_train, X_test

# %%
class MinMaxScaler:
    '''Scaling Time Series'''
    def __init__(self, minmax):
        self.scale_min, self.scale_min = minmax
        
    def fit(self, X):
        self.max_val = np.max(X)
        self.min_val = np.min(X)

    def transform(self, X):
        '''scale from min to max'''
        X = (self.scale_max - self.scale_min) * (X - self.min_val) / (self.max_val - self.min_val) + self.scale_min
        return X

# %%
class Standardize:
    '''Scaling Time Series'''
    def __init__(self):
        pass

    def fit(self, X):
        self.mean = np.mean(X)
        self.std = np.std(X)

    def transform(self, X):
        X = (X - self.mean) / (self.std + 1e-6)
        return X

# %% [markdown]
# Scale fit auf Nur die Normalen oder ganzes Trainingsset?
